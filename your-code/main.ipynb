# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x, y, color='green', linestyle=':', linewidth=2)
plt.plot(x, z, color='red', linestyle='--', linewidth=2)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True)
ax1.plot(y,z)
ax2.plot(x,y)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here 
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, sharex=True, sharey=True, figsize=(14,7))
ax1.plot(y,z)
ax2.plot(x,y)
ax1.set_title('exponential PLOT')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   


ax2.set_title('linear PLOT')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')
# Out:
# Text(0,0.5,'z label')

# %% [markdown]
# #### Plot both $y=x^2$ and $y=e^x$ in the same plot using normal and logarithmic scale.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
from math import e
fig, [ax1, ax2] = plt.subplots(nrows=1, ncols=2, figsize=(14,7))
ax1.plot(x**2)
ax1.plot(e**x)
ax1.set_xscale('log')
ax1.set_yscale('log')

ax2.plot(x**2)
ax2.plot(e**x)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
plt.plot(x**2, label = 'exponential')
plt.plot(e**x, label = 'logaritmic')
plt.xscale('log')
plt.yscale('log')
plt.legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
from sqlalchemy import create_engine
import pandas as pd
connection_string = 'mysql+pymysql://ironhacker_read:ir0nhack3r@35.239.232.23/fitbit'
    
engine = create_engine(connection_string)

query = """
        SELECT * FROM fitbit2
"""

fitbit = pd.read_csv('Fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
plt.plot(fitbit.groupby('Months_encoded').median()['Steps'])
plt.figure(figsize=(12,4))
plt.savefig('./figures/median_months.png')
plt.show()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fitbit.groupby('Work_or_Weekend').median()['Steps'].plot(kind='bar')
plt.savefig('./figures/week_or_wkend.png')
plt.show()

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
for i in ['Minutes Lightly Active','Minutes Very Active','Minutes Sedentary']:
    plt.scatter(fitbit['Steps'], fitbit[i],color='green', linewidths=0.1)
    plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
connection_string = 'mysql+pymysql://ironhacker_read:ir0nhack3r@35.239.232.23/titanic'
    
engine = create_engine(connection_string)

query = """
        SELECT * FROM titanic
"""
titanic = pd.read_csv('titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.dtypes
# Out:
# Unnamed: 0       int64
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64','float64']).columns
# Out:
# Index([u'Unnamed: 0', u'PassengerId', u'Survived', u'Pclass', u'Age', u'SibSp',
#        u'Parch', u'Fare'],
#       dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=['int64','float64']).columns
# Out:
# Index([u'Name', u'Gender', u'Ticket', u'Cabin', u'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
plt.figure(figsize=(12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
titanic['Age'].plot(kind='hist')

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
fig, axes = plt.subplots(3)
for size, axis in zip([10, 20, 50], axes):
    axis.hist(titanic['Age'], bins=size)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here:
frequence decrease as bins are smaller
"""
# Out:
# '\nyour comments here:\nfrequents decreases as bins are smaller\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
import seaborn as sns
sns.set()
sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
titanic.groupby('Gender').count()['Age'].plot(kind='bar')

# %%
# Method 2 - seaborn
# your code here
sns.barplot(titanic.groupby('Gender').count().index, titanic.groupby('Gender').count()['Age'])

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here
sns.barplot(titanic.groupby('Pclass').count().index, titanic.groupby('Pclass').count()['Age'])

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
mean=titanic['Age'].mean()
mode=titanic['Age'].mode().get_values()[0]

a = sns.boxplot(titanic['Age'])
a.axvline(mean, color='r', linestyle='--')
a.axvline(mode, color='b', linestyle='-')

# %%
"""
your comments here:
half of the people are inside the range of 22-35, as we see in the quartiles
"""
# Out:
# '\nyour comments here:\nhalf of the people are inside the range of 22-35, as we see in the quartiles\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here:
Boxplots give us all the info of the variable such as quartiles, median, iqr, mean, mode and even outliers
"""
# Out:
# '\nyour comments here:\nBoxplots give us all the info of the variable such as quartiles, median, iqr, mean, mode and even outliers\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
mean=titanic['Age'].mean()
mode=titanic['Age'].mode().get_values()[0]
median=titanic['Age'].median()

a = sns.distplot(titanic['Age'], kde=False)
a.axvline(mean, color='r', linestyle='--')
a.axvline(mode, color='b', linestyle='-')

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here:
distribution of the frequency of the Age, median, mean
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
plt.scatter(x=titanic['Age'], y=titanic['Fare'],)
plt.legend()

# %%
# Method 2 - seaborn
# your code here
sns.scatterplot(x=titanic['Age'], y=titanic['Fare'])

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here
sns.heatmap(titanic.corr())

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here:
SibSp and Parch
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
sns.boxplot(x=titanic['Pclass'], y=titanic['Age'])

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
sns.boxplot(x=titanic['Gender'], y=titanic['Age'])
